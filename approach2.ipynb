# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from statsmodels.miscmodels.ordinal_model import OrderedModel
import statsmodels.api as sm
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
wave7_csv = "data/preprocessed/filtered_wave_7.csv"
df = pd.read_csv(wave7_csv, low_memory=False)

# %%
# Path to your wave 7 CSV
wave7_csv = "data/preprocessed/filtered_wave_7.csv"

# Load CSV
df = pd.read_csv(wave7_csv, low_memory=False)

# G8 country codes
g8_codes = [840, 124, 250, 276, 380, 392, 643, 826]

# Filter for G8 countries
df_g8 = df[df["Country"].isin(g8_codes)].copy()

print("Shape of G8 data:", df_g8.shape)
df_g8.head()
# Out:
# Shape of G8 data: (13914, 14)
#        Country  Year  C Armed forces  C Television  C Police  C Courts  \
# 10072      124  2020               2             3         2         3
# 10073      124  2020               1             2         2         2
# 10074      124  2020               3             3         3         3
# 10075      124  2020               3             3         2         3
# 10076      124  2020               3             3         2         4
#
#        C Government  C Political parties  C Civil services  C Elections  \
# 10072             2                    3                 2            2
# 10073             1                    3                 2            1
# 10074             3                    3                 3            3
# 10075             3                    3                 3            2
# 10076             4                    4                 3            3
#
#        Importance of democracy  Highest educational level  Age  \
# 10072                       10                          7   76
# 10073                       10                          6   69
# 10074                        5                          3   35
# 10075                        8                          7   45
# 10076                       10                          6   32
#
#        Scale of incomes
# 10072                 9
# 10073                 3
# 10074                 3
# 10075                 7
# 10076                 5

# %%
# Assuming df_g8 is already loaded with G8 countries
# We will extract only the US subset
df_usa = df_g8[df_g8["Country"] == 840].copy()
print("Shape of data for USA:", df_usa.shape)
df_usa.head()
# Out:
# Shape of data for USA: (2596, 14)
#        Country  Year  C Armed forces  C Television  C Police  C Courts  \
# 89769      840  2017               3             2         4         4
# 89770      840  2017               2             3         2         2
# 89771      840  2017               2             3         2         2
# 89772      840  2017               2             3         2         2
# 89773      840  2017               2             3         2         2
#
#        C Government  C Political parties  C Civil services  C Elections  \
# 89769             4                    4                 4            4
# 89770             3                    4                 4            4
# 89771             2                    3                 3            3
# 89772             4                    4                 3            4
# 89773             4                    4                 4            3
#
#        Importance of democracy  Highest educational level  Age  \
# 89769                        2                          4   43
# 89770                        5                          2   35
# 89771                        1                          3   48
# 89772                       10                          3   49
# 89773                        5                          3   20
#
#        Scale of incomes
# 89769                 3
# 89770                 5
# 89771                 1
# 89772                 1
# 89773                 5

# %%
valid_conf = [1, 2, 3, 4]      # valid responses for confidence
valid_demo = list(range(1, 11)) # 1..10 for Importance of democracy
valid_educ = list(range(0, 9))  # 0..8 if you have 9 levels of edu
valid_income = list(range(1, 11)) # 1..10 for scale of incomes

df_clean = df_usa[
    df_usa["C Government"].isin(valid_conf) &
    df_usa["C Elections"].isin(valid_conf) &
    df_usa["C Political parties"].isin(valid_conf) &
    df_usa["C Police"].isin(valid_conf) &
    df_usa["C Courts"].isin(valid_conf) &
    df_usa["C Armed forces"].isin(valid_conf) &
    df_usa["C Civil services"].isin(valid_conf) &
    df_usa["Importance of democracy"].isin(valid_demo) &
    df_usa["Highest educational level"].isin(valid_educ) &
    df_usa["Scale of incomes"].isin(valid_income) &
    (df_usa["Age"] > 0)  # ensure Age is positive
].copy()

print("Shape after filtering invalid codes for USA:", df_clean.shape)
df_clean.head()
# Out:
# Shape after filtering invalid codes for USA: (2428, 14)
#        Country  Year  C Armed forces  C Television  C Police  C Courts  \
# 89769      840  2017               3             2         4         4
# 89770      840  2017               2             3         2         2
# 89771      840  2017               2             3         2         2
# 89772      840  2017               2             3         2         2
# 89773      840  2017               2             3         2         2
#
#        C Government  C Political parties  C Civil services  C Elections  \
# 89769             4                    4                 4            4
# 89770             3                    4                 4            4
# 89771             2                    3                 3            3
# 89772             4                    4                 3            4
# 89773             4                    4                 4            3
#
#        Importance of democracy  Highest educational level  Age  \
# 89769                        2                          4   43
# 89770                        5                          2   35
# 89771                        1                          3   48
# 89772                       10                          3   49
# 89773                        5                          3   20
#
#        Scale of incomes
# 89769                 3
# 89770                 5
# 89771                 1
# 89772                 1
# 89773                 5

# %%
df_clean = df_clean.rename(columns={
    "C Government": "gov_conf",
    "C Elections": "elect_conf",
    "C Political parties": "party_conf",
    "C Police": "police_conf",
    "C Courts": "courts_conf",
    "C Armed forces": "armed_conf",
    "C Civil services": "civil_conf",
    "Importance of democracy": "demo_import",
    "Highest educational level": "educ_level",
    "Scale of incomes": "income_scale",
    "Age": "age"
})

df_clean.head()
# Out:
#        Country  Year  armed_conf  C Television  police_conf  courts_conf  \
# 89769      840  2017           3             2            4            4
# 89770      840  2017           2             3            2            2
# 89771      840  2017           2             3            2            2
# 89772      840  2017           2             3            2            2
# 89773      840  2017           2             3            2            2
#
#        gov_conf  party_conf  civil_conf  elect_conf  demo_import  educ_level  \
# 89769         4           4           4           4            2           4
# 89770         3           4           4           4            5           2
# 89771         2           3           3           3            1           3
# 89772         4           4           3           4           10           3
# 89773         4           4           4           3            5           3
#
#        age  income_scale
# 89769   43             3
# 89770   35             5
# 89771   48             1
# 89772   49             1
# 89773   20             5

# %%
# Dependent variable = gov_conf (1..4)
y = df_clean["gov_conf"]

# List of predictors (feel free to remove or add as needed)
predictors = [
    "elect_conf", "party_conf", "police_conf", "courts_conf",
    "armed_conf", "civil_conf", "demo_import", "educ_level",
    "income_scale", "age"
]

# Subset the DataFrame to remove any row with NaN in these columns
df_model = df_clean.dropna(subset=["gov_conf"] + predictors)

# Reassign after dropping NaNs
y = df_model["gov_conf"]
X = df_model[predictors]

print("Shape of df_model after dropping NaNs:", df_model.shape)
X.head()
# Out:
# Shape of df_model after dropping NaNs: (2428, 14)
#        elect_conf  party_conf  police_conf  courts_conf  armed_conf  \
# 89769           4           4            4            4           3
# 89770           4           4            2            2           2
# 89771           3           3            2            2           2
# 89772           4           4            2            2           2
# 89773           3           4            2            2           2
#
#        civil_conf  demo_import  educ_level  income_scale  age
# 89769           4            2           4             3   43
# 89770           4            5           2             5   35
# 89771           3            1           3             1   48
# 89772           3           10           3             1   49
# 89773           4            5           3             5   20

# %%
# Instantiate the OrderedModel with a logit link
mod = OrderedModel(
    endog=y,
    exog=X,
    distr='logit'  # or 'probit'
)

# Fit the model
res = mod.fit(method='bfgs')
print("\nOrdered Logistic Regression Results for USA with multiple predictors:\n")
print(res.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 1.041141
#          Iterations: 41
#          Function evaluations: 45
#          Gradient evaluations: 45
#
# Ordered Logistic Regression Results for USA with multiple predictors:
#
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:               gov_conf   Log-Likelihood:                -2527.9
# Model:                   OrderedModel   AIC:                             5082.
# Method:            Maximum Likelihood   BIC:                             5157.
# Date:                Fri, 24 Jan 2025
# Time:                        16:13:12
# No. Observations:                2428
# Df Residuals:                    2415
# Df Model:                          10
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# elect_conf       0.4657      0.063      7.360      0.000       0.342       0.590
# party_conf       0.9679      0.077     12.491      0.000       0.816       1.120
# police_conf      0.8439      0.072     11.773      0.000       0.703       0.984
# courts_conf     -0.2232      0.071     -3.133      0.002      -0.363      -0.084
# armed_conf       0.7434      0.067     11.109      0.000       0.612       0.875
# civil_conf      -0.2360      0.069     -3.413      0.001      -0.372      -0.100
# demo_import      0.1297      0.021      6.308      0.000       0.089       0.170
# educ_level       0.1008      0.028      3.606      0.000       0.046       0.156
# income_scale    -0.0516      0.023     -2.232      0.026      -0.097      -0.006
# age             -0.0099      0.003     -3.806      0.000      -0.015      -0.005
# 1/2              3.9789      0.359     11.072      0.000       3.275       4.683
# 2/3              0.8009      0.039     20.322      0.000       0.724       0.878
# 3/4              0.8072      0.030     27.259      0.000       0.749       0.865
# ================================================================================
